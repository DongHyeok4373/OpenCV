# %%
# !pythion --version
# Out:
# /bin/bash: line 1: pythion: command not found

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/cat.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=227x223>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/lena256.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imsho(gimg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-aa74a4fd1bae> in <cell line: 1>()
# ----> 1 gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#       2 print(gimg.shape)
#       3 plt.imsho(gimg, cmap='gray')
#
# NameError: name 'RGB_img' is not defined

# %%
gPlus =  np

# %%
val = 50

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    plusVal =gimg[h,w]+val
    if(plusVal > 255):
      plusVal=255
    gPlus[h,w]=plusVal

plt.imshow(gPlus, cmap = 'gray')
