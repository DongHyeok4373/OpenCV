# %%
# !pythion --version
# Out:
# /bin/bash: line 1: pythion: command not found

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/milkdrop.bmp')

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
T1=50
T2=0
T0=1

# %%
output_img = np.zeros((gray_img.shape[0],gray_img.shape[1]))

# %%
def threshold_update(h,w,img,outpt,T1):
  sum1=0
  count1=1
  sum2=0
  count2=1
  for h in range(img.shape[0]):
    for w in range(img.shape[1]):
      if(output[h,w]==255):
        sum1 = sum1 + img[h,w]
        count1 = count1 + 1
      else:
        sum2 = sum2 + img[h,w]
        count2 = count2 + 1
  ave1 = sum1/count1
  ave2 = sum2/count2
  T2 = np.int32(ave1+ave2)/2
  return T2

# %%
for h in range(gray_img.shape[0]):
  for w in range(gray_img.shape[1]):
    if(gray_img[h,w]>T1):
      output_img[h,w]=255
    else:
      output_img[h,w]=0

# %%
while True:
  T2 = threshold_update(gray_img.shape[0],gray_img.shape[1],gray_img,output_img,T1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9c10167fc13b> in <cell line: 1>()
#       1 while True:
# ----> 2   T2 = threshold_update(gray_img.shape[0],gray_img.shape[1],gray_img,output_img,T1)
#
# <ipython-input-12-011469c63d1b> in threshold_update(h, w, img, outpt, T1)
#       6   for h in range(img.shape[0]):
#       7     for w in range(img.shape[1]):
# ----> 8       if(output[h,w]==255):
#       9         sum1 = sum1 + img[h,w]
#      10         count1 = count1 + 1
#
# NameError: name 'output' is not defined
