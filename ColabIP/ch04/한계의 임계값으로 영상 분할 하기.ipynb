# %%
# !pythion --version
# Out:
# /bin/bash: line 1: pythion: command not found

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
img1 = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/cell.bmp')

# %%
RGB_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
output_img = np.zeros((RGB_img1.shape[0],RGB_img1.shape[1]))

# %%
for h in range(RGB_img1.shape[0]):
  for w in range(RGB_img1.shape[1]):
    if(np.int32(RGB_img1[h,w][0])<140):
      output_img[h,w]=255
    else:
      output_img[h,w]=0

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.title("Image1")
plt.imshow(RGB_img1)
plt.axis("off")
plt.subplot(1,2,2)
plt.title("Segmented Image")
plt.imshow(output_img, cmap='gray')
plt.axis("off")
plt.show()
