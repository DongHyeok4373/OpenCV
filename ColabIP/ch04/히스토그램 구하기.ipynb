# %%
# !pythion --version
# Out:
# /bin/bash: line 1: pythion: command not found

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img1 = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/lena.jpg')

# %%
RGB_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
R_img1,G_img1,B_img1 = cv2.split(RGB_img1)

# %%
plt.figure(figsize=(20,20))
plt.subplot(111), plt.imshow(RGB_img1)
plt.axis("off")
hist = cv2.calcHist([R_img1],[0],None,[256],[0,255])
plt.subplot(112), plt.plot(hist,color = 'r')
plt.xlim([0,256])
hist = cv2.calcHist([G_img1],[0],None,[256],[0,255])
plt.plot(hist,color = 'g')
plt.xlim([0,255])
hist = cv2.calcHist([B_img1],[0],None,[256],[0,255])
plt.plot(hist,color = 'b')
plt.xlim([0,255])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-511e00b788d2> in <cell line: 5>()
#       3 plt.axis("off")
#       4 hist = cv2.calcHist([R_img1],[0],None,[256],[0,255])
# ----> 5 plt.subplot(112), plt.plot(hist,color = 'r')
#       6 plt.xlim([0,256])
#       7 hist = cv2.calcHist([G_img1],[0],None,[256],[0,255])
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1321
#    1322     # First, search for an existing subplot with a matching spec.
# -> 1323     key = SubplotSpec._from_subplot_args(fig, args)
#    1324
#    1325     for ax in fig.axes:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     596         else:
#     597             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598                 raise ValueError(
#     599                     f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600                     f"not {num!r}"
#
# ValueError: num must be an integer with 1 <= num <= 1, not 2
